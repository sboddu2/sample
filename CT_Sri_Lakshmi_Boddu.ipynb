# %% [markdown]
# <a href="https://colab.research.google.com/github/sboddu2/sample/blob/main/CT_Sri_Lakshmi_Boddu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
requests.get("https://randomuser.me/api/")
# Out:
# <Response [200]>

# %%
response = requests.get("https://randomuser.me/api/")
response.json()
# Out:
# {'results': [{'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Grigoriy', 'last': 'Asaula'},
#    'location': {'street': {'number': 6879, 'name': 'Uzhgorodskiy provulok'},
#     'city': 'Pomichna',
#     'state': 'Poltavska',
#     'country': 'Ukraine',
#     'postcode': 60445,
#     'coordinates': {'latitude': '74.3581', 'longitude': '-82.3542'},
#     'timezone': {'offset': '+3:30', 'description': 'Tehran'}},
#    'email': 'grigoriy.asaula@example.com',
#    'login': {'uuid': '409beba8-f12d-4739-b913-b54bf393be83',
#     'username': 'bigduck722',
#     'password': 'marijuan',
#     'salt': '8di1DnMT',
#     'md5': '120ecb89fad84c8264c8ea69d7dbeb98',
#     'sha1': '1577c08a1cffb9c489e09c2f9f97cad8b212870b',
#     'sha256': '3585ae26495b57482df352b9c91e0aa18a0f37fa28531d00d7189e5a612a1d3c'},
#    'dob': {'date': '1965-09-29T18:23:48.776Z', 'age': 57},
#    'registered': {'date': '2008-05-20T21:25:03.172Z', 'age': 14},
#    'phone': '(099) G62-7951',
# ...

# %%
response = requests.get("https://randomuser.me/api/?nat=fr&gender=male")
response.json()
# Out:
# {'results': [{'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Cléo', 'last': 'Barbier'},
#    'location': {'street': {'number': 1187, 'name': "Rue de L'Abbé-Carton"},
#     'city': 'Orléans',
#     'state': 'Val-de-Marne',
#     'country': 'France',
#     'postcode': 61802,
#     'coordinates': {'latitude': '-47.8101', 'longitude': '-121.5327'},
#     'timezone': {'offset': '-10:00', 'description': 'Hawaii'}},
#    'email': 'cleo.barbier@example.com',
#    'login': {'uuid': '0118ae9e-2adf-47af-9d33-d85f794537bb',
#     'username': 'smallduck314',
#     'password': 'socks',
#     'salt': '4lO28BN0',
#     'md5': '66c0826c22ad4f0b9674e92e5ec90f8b',
#     'sha1': '4780a9368cad283cf5d7c4c434cba71fdc14b306',
#     'sha256': '788a184b30cc941468e331541e879f245f399cdb212fdabec793d8ff158e7473'},
#    'dob': {'date': '1993-06-14T08:12:59.973Z', 'age': 29},
#    'registered': {'date': '2013-06-23T17:41:09.262Z', 'age': 9},
#    'phone': '05-45-33-24-77',
#    'cell': '06-07-32-30-74',
# ...

# %%
response = requests.get("https://randomuser.me/api/?results=10&nat=us,gb&gender=female")
response.json()
# Out:
# {'results': [{'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Teresa', 'last': 'Gonzalez'},
#    'location': {'street': {'number': 1700, 'name': 'Oaks Cross'},
#     'city': 'Wakefield',
#     'state': 'Cornwall',
#     'country': 'United Kingdom',
#     'postcode': 'S0R 4LP',
#     'coordinates': {'latitude': '0.1510', 'longitude': '161.7201'},
#     'timezone': {'offset': '-2:00', 'description': 'Mid-Atlantic'}},
#    'email': 'teresa.gonzalez@example.com',
#    'login': {'uuid': '5a628e2a-033a-4921-a4e5-d23679ce4eeb',
#     'username': 'tinyfrog832',
#     'password': 'donnie',
#     'salt': 'clnPMhel',
#     'md5': 'e2e8eed4f1ad4e47a996e0f74dfce6e6',
#     'sha1': 'b04e01b4866b09e6145434ad57cbd42999e7291a',
#     'sha256': 'fc9b87d8030c1eb4b542c8649ed2476507603ced4f0b3992ce6b0f8ef912be0a'},
#    'dob': {'date': '1952-09-03T09:52:55.685Z', 'age': 70},
#    'registered': {'date': '2006-06-11T20:57:07.870Z', 'age': 16},
#    'phone': '015396 68060',
# ...
